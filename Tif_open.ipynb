# %%
# %matplotlib widget

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Open the tif image.

# %%
# Image url

imUrl = '/export/work/Satdata2/scmos/2_20_11_34.tif'

# %% [markdown]
# We now can have a look at what the file contains

# %%
im = plt.imread(imUrl)
display(im)

# %%
plt.imshow(im,cmap='gray',vmax=200)
display(np.min(im),np.max(im))
plt.show()
